# %%
import pandas as pd

# %%
df = pd.read_csv('demo.csv')

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# %%
pd.DataFrame(scaled_df)
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.448652  0.590668  0.052933  0.523568 -0.041115 -0.589367 -0.043569
# 1    1.448652  0.590668 -0.391302  0.544458  0.170318 -0.270136  0.086407
# 2    1.448652  0.590668 -0.447029  0.408538 -0.028157 -0.137536  0.133232
# 3   -0.690297  0.590668  0.100111 -0.624020 -0.392977  0.687144 -0.498588
# 4    1.448652  0.590668  0.840239 -0.052396 -0.079356  0.173859 -0.231918
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.690297  0.590668  1.401312  0.848446  0.850760  2.075222 -0.566831
# 436 -0.690297  0.590668  2.155293 -0.592142 -0.757165  0.296561 -0.585519
# 437  1.448652  0.590668  0.200326  1.314671  2.348386 -0.543380  2.511218
# 438 -0.690297  0.590668 -0.135384 -0.517536 -0.602514 -0.419441 -0.569770
# 439 -0.690297  0.590668 -0.729307 -0.555924 -0.573227 -0.620094 -0.504888
#
#             7
# 0   -0.066339
# 1    0.089151
# 2    2.243293
# 3    0.093411
# ...

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(scaled_df)
# Out:
# C:\Users\hussa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\hussa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
kmeans.inertia_
# Out:
# 2599.3844237836256

# %%
inertias = []

# %%
for cluster in range(1, 21):  # Start range at 1 to avoid n_clusters being set to 0
    kmeans = KMeans(n_clusters=cluster)
    kmeans.fit(scaled_df)
    inertias.append(kmeans.inertia_)  # Correctly append inertia to the list
# Out:
# C:\Users\hussa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\hussa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\hussa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
frames = pd.DataFrame("Clusters":range(1,20), "inertias":
